# %% [markdown]
# # River Flow Anomaly Detection and Correction
#
# Method 1: Hampel Filter + Interpolation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import median_abs_deviation

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

file_path = "river_data.xlsx"

df = pd.read_excel(
    file_path,
    header=2
)

# Remove catchment area row
df = df.iloc[1:].reset_index(drop=True)

# Keep only first four columns
df = df.iloc[:, :4]

df.columns = [
    'datetime',
    'tributary_A',
    'tributary_B',
    'combined_river'
]

df['datetime'] = pd.to_datetime(df['datetime'])

df['tributary_A'] = pd.to_numeric(df['tributary_A'])
df['tributary_B'] = pd.to_numeric(df['tributary_B'])
df['combined_river'] = pd.to_numeric(df['combined_river'])

df.head()
# Out:
#              datetime  tributary_A  tributary_B  combined_river
# 0 2002-05-01 01:00:00        755.3   867.262870         2787.55
# 1 2002-05-01 02:00:00        755.3   867.262870         2691.52
# 2 2002-05-01 03:00:00        784.5   809.916908         2596.59
# 3 2002-05-01 04:00:00        784.5   809.916908         2491.12
# 4 2002-05-01 05:00:00        784.5   701.249553         2421.59

# %% [markdown]
# ## Initial Visualization

# %%
plt.figure(figsize=(15,5))
plt.plot(df['datetime'], df['tributary_A'])
plt.title('Tributary A Flow')
plt.show()

# %% [markdown]
# ## Hampel Filter Function

# %%
def hampel_filter(series, window_size=12, n_sigmas=3):

    series = series.copy()
    anomalies = []

    for i in range(window_size, len(series)-window_size):

        window = series[i-window_size:i+window_size+1]

        median = np.median(window)

        mad = median_abs_deviation(
            window,
            scale='normal'
        )

        if mad == 0:
            continue

        deviation = abs(series.iloc[i] - median)

        if deviation > n_sigmas * mad:
            anomalies.append(i)

    return anomalies

# %% [markdown]
# ## Detect Anomalies

# %%
anomalies_A = hampel_filter(df['tributary_A'])
anomalies_B = hampel_filter(df['tributary_B'])

print('A anomalies:', len(anomalies_A))
print('B anomalies:', len(anomalies_B))
# Out:
# A anomalies: 334
# B anomalies: 192

# %% [markdown]
# ## Visualize Detected Anomalies

# %%
plt.figure(figsize=(15,5))

plt.plot(
    df['datetime'],
    df['tributary_A'],
    label='Original'
)

plt.scatter(
    df.loc[anomalies_A, 'datetime'],
    df.loc[anomalies_A, 'tributary_A'],
    color='red',
    label='Anomaly'
)

plt.legend()
plt.show()

# %% [markdown]
# ## Replace Anomalies with NaN

# %%
df_clean = df.copy()

df_clean.loc[anomalies_A, 'tributary_A'] = np.nan
df_clean.loc[anomalies_B, 'tributary_B'] = np.nan

# %% [markdown]
# ## Interpolate Missing Values

# %%
df_clean['tributary_A'] = (
    df_clean['tributary_A']
    .interpolate(method='linear')
)

df_clean['tributary_B'] = (
    df_clean['tributary_B']
    .interpolate(method='linear')
)

# %% [markdown]
# ## Compare Before and After

# %%
plt.figure(figsize=(15,5))

plt.plot(
    df['datetime'],
    df['tributary_A'],
    label='Original',
    alpha=0.6
)

plt.plot(
    df_clean['datetime'],
    df_clean['tributary_A'],
    label='Cleaned'
)

plt.legend()
plt.show()

# %% [markdown]
# ## Clean Combined River

# %%
anomalies_C = hampel_filter(df['combined_river'])

df_clean.loc[anomalies_C, 'combined_river'] = np.nan

df_clean['combined_river'] = (
    df_clean['combined_river']
    .interpolate()
)

# %% [markdown]
# ## Save Cleaned Dataset

# %%
df_clean.rename(columns={
    'tributary_A': 'Tamen',
    'tributary_B': 'Daporizo',
    'combined_river': 'Gerukamukh'
}, inplace=True)

df_clean.to_excel(
    'cleaned_hampel.xlsx',
    index=False
)

print('Saved: cleaned_hampel.xlsx')

print("Tributary A:", len(anomalies_A))

print("Tributary B:", len(anomalies_B))

print("Combined River:", len(anomalies_C))



for idx in anomalies_A[:5]:

    print("\nAnomaly at index:", idx)

    print(df.iloc[idx-3:idx+4])
# Out:
# Saved: cleaned_hampel.xlsx
# Tributary A: 334
# Tributary B: 192
# Combined River: 240
#
# Anomaly at index: 24
#               datetime  tributary_A  tributary_B  combined_river
# 21 2002-05-01 22:00:00       784.50   454.016564         1508.74
# 22 2002-05-01 23:00:00       755.30   443.609909         1488.98
# 23 2002-05-02 00:00:00       755.30   443.609909         1488.00
# 24 2002-05-02 01:00:00      1216.34   443.609909         1459.51
# 25 2002-05-02 02:00:00      1216.34   443.609909         1449.72
# 26 2002-05-02 03:00:00      1179.66   433.326937         1439.96
# 27 2002-05-02 04:00:00      1143.55   433.326937         1401.13
#
# Anomaly at index: 25
#               datetime  tributary_A  tributary_B  combined_river
# 22 2002-05-01 23:00:00       755.30   443.609909         1488.98
# 23 2002-05-02 00:00:00       755.30   443.609909         1488.00
# 24 2002-05-02 01:00:00      1216.34   443.609909         1459.51
# 25 2002-05-02 02:00:00      1216.34   443.609909         1449.72
# 26 2002-05-02 03:00:00      1179.66   433.326937         1439.96
# 27 2002-05-02 04:00:00      1143.55   433.326937         1401.13
# 28 2002-05-02 05:00:00      1143.55   433.326937         1362.64
#
# Anomaly at index: 26
#               datetime  tributary_A  tributary_B  combined_river
# 23 2002-05-02 00:00:00       755.30   443.609909         1488.00
# 24 2002-05-02 01:00:00      1216.34   443.609909         1459.51
# 25 2002-05-02 02:00:00      1216.34   443.609909         1449.72
# 26 2002-05-02 03:00:00      1179.66   433.326937         1439.96
# 27 2002-05-02 04:00:00      1143.55   433.326937         1401.13
# 28 2002-05-02 05:00:00      1143.55   433.326937         1362.64
# 29 2002-05-02 06:00:00      1108.03   433.326937         1362.64
#
# Anomaly at index: 29
#               datetime  tributary_A  tributary_B  combined_river
# 26 2002-05-02 03:00:00      1179.66   433.326937         1439.96
# 27 2002-05-02 04:00:00      1143.55   433.326937         1401.13
# 28 2002-05-02 05:00:00      1143.55   433.326937         1362.64
# 29 2002-05-02 06:00:00      1108.03   433.326937         1362.64
# 30 2002-05-02 07:00:00      1004.93   423.167572         1372.23
# 31 2002-05-02 08:00:00       726.68   423.167572         1362.64
# 32 2002-05-02 09:00:00       726.68   423.167572         1362.64
#
# Anomaly at index: 146
#                datetime  tributary_A  tributary_B  combined_river
# 143 2002-05-07 00:00:00       542.23   355.506691         1157.29
# 144 2002-05-07 01:00:00       755.30   364.802930         1121.13
# 145 2002-05-07 02:00:00       755.30   374.222239         1121.13
# 146 2002-05-07 03:00:00       784.50   374.222239         1112.15
# 147 2002-05-07 04:00:00       784.50   464.546973         1103.19
# 148 2002-05-07 05:00:00       784.50   374.222239         1103.19
# 149 2002-05-07 06:00:00       784.50   374.222239         1103.19
